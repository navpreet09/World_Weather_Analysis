# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs =zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 721

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]

        city_weather =city_weather["weather"][0]["description"] 
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather})    
        
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | pevek
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | mehamn
# Processing Record 7 of Set 1 | acurenam
# Processing Record 8 of Set 1 | marawi
# Processing Record 9 of Set 1 | yurla
# Processing Record 10 of Set 1 | tiksi
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | khatanga
# Processing Record 13 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 1 | jalu
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | torbay
# Processing Record 19 of Set 1 | solnechnyy
# Processing Record 20 of Set 1 | dingle
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | shache
# Processing Record 24 of Set 1 | salta
# Processing Record 25 of Set 1 | cherskiy
# Processing Record 26 of Set 1 | constanta
# Processing Record 27 of Set 1 | bembereke
# Processing Record 28 of Set 1 | naze
# Processing Record 29 of Set 1 | anadyr
# Processing Record 30 of Set 1 | alofi
# Processing Record 31 of Set 1 | kumbo
# Processing Record 32 of Set 1 | las varas
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | lagoa
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 1 | hovd
# Processing Record 38 of Set 1 | jumla
# Processing Record 39 of Set 1 | yirol
# City not found. Skipping...
# Processing Record 40 of Set 1 | cabo san lucas
# Processing Record 41 of Set 1 | provideniya
# Processing Record 42 of Set 1 | beisfjord
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | geraldton
# Processing Record 45 of Set 1 | lebu
# Processing Record 46 of Set 1 | bambous virieux
# Processing Record 47 of Set 1 | yining
# Processing Record 48 of Set 1 | komsomolskiy
# Processing Record 49 of Set 1 | sabha
# Processing Record 50 of Set 1 | ucluelet
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | manacapuru
# Processing Record 3 of Set 2 | jizan
# Processing Record 4 of Set 2 | kardla
# Processing Record 5 of Set 2 | varkaus
# Processing Record 6 of Set 2 | muroto
# Processing Record 7 of Set 2 | gaborone
# Processing Record 8 of Set 2 | andenes
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 10 of Set 2 | angoche
# Processing Record 11 of Set 2 | ahipara
# Processing Record 12 of Set 2 | praya
# Processing Record 13 of Set 2 | tazovskiy
# Processing Record 14 of Set 2 | mount gambier
# Processing Record 15 of Set 2 | tsaratanana
# Processing Record 16 of Set 2 | bilibino
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | guadalupe y calvo
# Processing Record 19 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 2 | fort nelson
# Processing Record 21 of Set 2 | valdivia
# Processing Record 22 of Set 2 | san patricio
# Processing Record 23 of Set 2 | bethel
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | phan thiet
# Processing Record 26 of Set 2 | pampa
# Processing Record 27 of Set 2 | dickinson
# Processing Record 28 of Set 2 | aquiraz
# Processing Record 29 of Set 2 | nemuro
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | jibuti
# Processing Record 32 of Set 2 | hue
# Processing Record 33 of Set 2 | castro
# Processing Record 34 of Set 2 | verkhnevilyuysk
# Processing Record 35 of Set 2 | luderitz
# Processing Record 36 of Set 2 | saint anthony
# Processing Record 37 of Set 2 | east london
# Processing Record 38 of Set 2 | northam
# Processing Record 39 of Set 2 | tasiilaq
# Processing Record 40 of Set 2 | police
# Processing Record 41 of Set 2 | bangui
# Processing Record 42 of Set 2 | barkot
# Processing Record 43 of Set 2 | lorengau
# Processing Record 44 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 2 | urumqi
# Processing Record 46 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 2 | kasongo-lunda
# Processing Record 48 of Set 2 | kloulklubed
# Processing Record 49 of Set 2 | barrow
# Processing Record 50 of Set 2 | yellowknife
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | carnarvon
# Processing Record 3 of Set 3 | namatanai
# Processing Record 4 of Set 3 | palu
# Processing Record 5 of Set 3 | saint-philippe
# Processing Record 6 of Set 3 | salalah
# Processing Record 7 of Set 3 | qaanaaq
# Processing Record 8 of Set 3 | hamilton
# Processing Record 9 of Set 3 | airai
# Processing Record 10 of Set 3 | saldanha
# Processing Record 11 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 3 | amuntai
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | alma
# Processing Record 15 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 16 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 17 of Set 3 | sabang
# Processing Record 18 of Set 3 | kizilskoye
# Processing Record 19 of Set 3 | florianopolis
# Processing Record 20 of Set 3 | southbridge
# Processing Record 21 of Set 3 | nanortalik
# Processing Record 22 of Set 3 | chara
# Processing Record 23 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 3 | wote
# Processing Record 25 of Set 3 | tuatapere
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | mahebourg
# Processing Record 28 of Set 3 | jamestown
# Processing Record 29 of Set 3 | longyearbyen
# Processing Record 30 of Set 3 | santiago de cuba
# Processing Record 31 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 3 | tierranueva
# Processing Record 33 of Set 3 | punta arenas
# Processing Record 34 of Set 3 | tessalit
# Processing Record 35 of Set 3 | mabaruma
# Processing Record 36 of Set 3 | kaitangata
# Processing Record 37 of Set 3 | yerbogachen
# Processing Record 38 of Set 3 | busselton
# Processing Record 39 of Set 3 | khandyga
# Processing Record 40 of Set 3 | biak
# Processing Record 41 of Set 3 | timra
# Processing Record 42 of Set 3 | nikolskoye
# Processing Record 43 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 44 of Set 3 | eyl
# Processing Record 45 of Set 3 | rio gallegos
# Processing Record 46 of Set 3 | asandh
# Processing Record 47 of Set 3 | lavrentiya
# Processing Record 48 of Set 3 | clyde river
# Processing Record 49 of Set 3 | berlevag
# Processing Record 50 of Set 3 | iskateley
# Processing Record 1 of Set 4 | yumen
# Processing Record 2 of Set 4 | necochea
# Processing Record 3 of Set 4 | port elizabeth
# Processing Record 4 of Set 4 | mindelo
# Processing Record 5 of Set 4 | hithadhoo
# Processing Record 6 of Set 4 | slave lake
# Processing Record 7 of Set 4 | cockburn town
# Processing Record 8 of Set 4 | sao joao da barra
# Processing Record 9 of Set 4 | sabzevar
# Processing Record 10 of Set 4 | kharan
# Processing Record 11 of Set 4 | bhayavadar
# Processing Record 12 of Set 4 | souillac
# Processing Record 13 of Set 4 | katsuura
# Processing Record 14 of Set 4 | namibe
# Processing Record 15 of Set 4 | saint-pierre
# Processing Record 16 of Set 4 | thompson
# Processing Record 17 of Set 4 | padang
# Processing Record 18 of Set 4 | talara
# Processing Record 19 of Set 4 | khartoum
# Processing Record 20 of Set 4 | leningradskiy
# Processing Record 21 of Set 4 | vesyegonsk
# Processing Record 22 of Set 4 | belem de sao francisco
# Processing Record 23 of Set 4 | hermanus
# Processing Record 24 of Set 4 | douentza
# Processing Record 25 of Set 4 | escarcega
# Processing Record 26 of Set 4 | waipawa
# Processing Record 27 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 4 | sheridan
# Processing Record 29 of Set 4 | alassio
# Processing Record 30 of Set 4 | laguna
# Processing Record 31 of Set 4 | upernavik
# Processing Record 32 of Set 4 | sola
# Processing Record 33 of Set 4 | eureka
# Processing Record 34 of Set 4 | maragogi
# Processing Record 35 of Set 4 | hasaki
# Processing Record 36 of Set 4 | norman wells
# Processing Record 37 of Set 4 | klyuchi
# Processing Record 38 of Set 4 | coral springs
# Processing Record 39 of Set 4 | bolitoc
# Processing Record 40 of Set 4 | arraial do cabo
# Processing Record 41 of Set 4 | zhuhai
# Processing Record 42 of Set 4 | chuy
# Processing Record 43 of Set 4 | itarema
# Processing Record 44 of Set 4 | porto empedocle
# Processing Record 45 of Set 4 | ambilobe
# Processing Record 46 of Set 4 | xai-xai
# Processing Record 47 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 48 of Set 4 | acapulco
# Processing Record 49 of Set 4 | poum
# Processing Record 50 of Set 4 | port lincoln
# Processing Record 1 of Set 5 | manta
# Processing Record 2 of Set 5 | pisco
# Processing Record 3 of Set 5 | dubbo
# Processing Record 4 of Set 5 | ambunti
# Processing Record 5 of Set 5 | bac lieu
# Processing Record 6 of Set 5 | egvekinot
# Processing Record 7 of Set 5 | port hardy
# Processing Record 8 of Set 5 | nuuk
# Processing Record 9 of Set 5 | sarangani
# Processing Record 10 of Set 5 | atambua
# Processing Record 11 of Set 5 | odugathur
# City not found. Skipping...
# Processing Record 12 of Set 5 | catumbela
# Processing Record 13 of Set 5 | chokurdakh
# Processing Record 14 of Set 5 | hasanpur
# Processing Record 15 of Set 5 | bengkulu
# Processing Record 16 of Set 5 | hailar
# Processing Record 17 of Set 5 | puerto cortes
# City not found. Skipping...
# Processing Record 18 of Set 5 | kungurtug
# Processing Record 19 of Set 5 | den helder
# Processing Record 20 of Set 5 | kutum
# Processing Record 21 of Set 5 | iqaluit
# Processing Record 22 of Set 5 | sayyan
# Processing Record 23 of Set 5 | faya
# Processing Record 24 of Set 5 | deputatskiy
# Processing Record 25 of Set 5 | berdigestyakh
# Processing Record 26 of Set 5 | saint george
# Processing Record 27 of Set 5 | ilulissat
# Processing Record 28 of Set 5 | lisakovsk
# Processing Record 29 of Set 5 | leeton
# Processing Record 30 of Set 5 | yurga
# Processing Record 31 of Set 5 | mahibadhoo
# Processing Record 32 of Set 5 | la ronge
# Processing Record 33 of Set 5 | port macquarie
# Processing Record 34 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 5 | el campo
# Processing Record 37 of Set 5 | adrar
# Processing Record 38 of Set 5 | broome
# Processing Record 39 of Set 5 | soke
# Processing Record 40 of Set 5 | hvolsvollur
# Processing Record 41 of Set 5 | zhigansk
# Processing Record 42 of Set 5 | the valley
# Processing Record 43 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 5 | paciran
# Processing Record 45 of Set 5 | buala
# Processing Record 46 of Set 5 | pallasovka
# Processing Record 47 of Set 5 | saskylakh
# Processing Record 48 of Set 5 | yulara
# Processing Record 49 of Set 5 | henderson
# Processing Record 50 of Set 5 | raahe
# Processing Record 1 of Set 6 | san quintin
# Processing Record 2 of Set 6 | pangnirtung
# Processing Record 3 of Set 6 | husavik
# Processing Record 4 of Set 6 | cidreira
# Processing Record 5 of Set 6 | santa maria
# Processing Record 6 of Set 6 | goderich
# Processing Record 7 of Set 6 | hwange
# Processing Record 8 of Set 6 | hearst
# Processing Record 9 of Set 6 | touros
# Processing Record 10 of Set 6 | martinez
# Processing Record 11 of Set 6 | aksarka
# Processing Record 12 of Set 6 | totness
# Processing Record 13 of Set 6 | kavieng
# Processing Record 14 of Set 6 | shingu
# Processing Record 15 of Set 6 | aklavik
# Processing Record 16 of Set 6 | pimentel
# Processing Record 17 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 6 | belaya gora
# Processing Record 19 of Set 6 | sitka
# Processing Record 20 of Set 6 | faanui
# Processing Record 21 of Set 6 | prince rupert
# Processing Record 22 of Set 6 | fairbanks
# Processing Record 23 of Set 6 | shaunavon
# Processing Record 24 of Set 6 | flinders
# Processing Record 25 of Set 6 | pacific grove
# Processing Record 26 of Set 6 | guerrero negro
# Processing Record 27 of Set 6 | kohtla-jarve
# Processing Record 28 of Set 6 | sur
# Processing Record 29 of Set 6 | victoria
# Processing Record 30 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 31 of Set 6 | port-gentil
# Processing Record 32 of Set 6 | ballina
# Processing Record 33 of Set 6 | waitara
# Processing Record 34 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 35 of Set 6 | qafsah
# City not found. Skipping...
# Processing Record 36 of Set 6 | shubarkuduk
# Processing Record 37 of Set 6 | ajdabiya
# Processing Record 38 of Set 6 | milingimbi
# City not found. Skipping...
# Processing Record 39 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 6 | somogyvar
# Processing Record 41 of Set 6 | broken hill
# Processing Record 42 of Set 6 | cape town
# Processing Record 43 of Set 6 | talnakh
# Processing Record 44 of Set 6 | sidi ali
# Processing Record 45 of Set 6 | namwala
# Processing Record 46 of Set 6 | gamba
# Processing Record 47 of Set 6 | kudahuvadhoo
# Processing Record 48 of Set 6 | taoudenni
# Processing Record 49 of Set 6 | colomi
# Processing Record 50 of Set 6 | juarez
# Processing Record 1 of Set 7 | ulaangom
# Processing Record 2 of Set 7 | harper
# Processing Record 3 of Set 7 | peniche
# Processing Record 4 of Set 7 | mar del plata
# Processing Record 5 of Set 7 | crateus
# Processing Record 6 of Set 7 | kenora
# Processing Record 7 of Set 7 | jasper
# Processing Record 8 of Set 7 | paamiut
# Processing Record 9 of Set 7 | preeceville
# Processing Record 10 of Set 7 | lucea
# Processing Record 11 of Set 7 | udachnyy
# Processing Record 12 of Set 7 | calama
# Processing Record 13 of Set 7 | hay river
# Processing Record 14 of Set 7 | haines junction
# Processing Record 15 of Set 7 | bathsheba
# Processing Record 16 of Set 7 | bredasdorp
# Processing Record 17 of Set 7 | murupara
# Processing Record 18 of Set 7 | tamiahua
# Processing Record 19 of Set 7 | kaeo
# Processing Record 20 of Set 7 | vyazma
# Processing Record 21 of Set 7 | muyezerskiy
# Processing Record 22 of Set 7 | kerema
# Processing Record 23 of Set 7 | valverde del camino
# Processing Record 24 of Set 7 | kismayo
# Processing Record 25 of Set 7 | hofn
# Processing Record 26 of Set 7 | grong
# Processing Record 27 of Set 7 | kleck
# City not found. Skipping...
# Processing Record 28 of Set 7 | at-bashi
# Processing Record 29 of Set 7 | kahului
# Processing Record 30 of Set 7 | asau
# Processing Record 31 of Set 7 | isangel
# Processing Record 32 of Set 7 | margate
# Processing Record 33 of Set 7 | ponta do sol
# Processing Record 34 of Set 7 | kununurra
# Processing Record 35 of Set 7 | khasan
# Processing Record 36 of Set 7 | nabire
# Processing Record 37 of Set 7 | praia
# Processing Record 38 of Set 7 | vanavara
# Processing Record 39 of Set 7 | glendive
# Processing Record 40 of Set 7 | bollnas
# Processing Record 41 of Set 7 | ostrovnoy
# Processing Record 42 of Set 7 | sarankhola
# Processing Record 43 of Set 7 | am timan
# Processing Record 44 of Set 7 | vizianagaram
# Processing Record 45 of Set 7 | gigmoto
# Processing Record 46 of Set 7 | ixtapa
# Processing Record 47 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 7 | van
# Processing Record 49 of Set 7 | nome
# Processing Record 50 of Set 7 | cao bang
# Processing Record 1 of Set 8 | yuzhno-kurilsk
# Processing Record 2 of Set 8 | sisimiut
# Processing Record 3 of Set 8 | saint-augustin
# Processing Record 4 of Set 8 | kirakira
# Processing Record 5 of Set 8 | floro
# Processing Record 6 of Set 8 | lompoc
# Processing Record 7 of Set 8 | diu
# Processing Record 8 of Set 8 | batemans bay
# Processing Record 9 of Set 8 | bamako
# Processing Record 10 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 11 of Set 8 | vestmannaeyjar
# Processing Record 12 of Set 8 | chumikan
# Processing Record 13 of Set 8 | oistins
# Processing Record 14 of Set 8 | turukhansk
# Processing Record 15 of Set 8 | hernani
# Processing Record 16 of Set 8 | greytown
# Processing Record 17 of Set 8 | bonthe
# Processing Record 18 of Set 8 | nizhniy tsasuchey
# Processing Record 19 of Set 8 | ust-kulom
# Processing Record 20 of Set 8 | banmo
# City not found. Skipping...
# Processing Record 21 of Set 8 | khanpur
# Processing Record 22 of Set 8 | bubaque
# Processing Record 23 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 24 of Set 8 | sinnamary
# Processing Record 25 of Set 8 | port hedland
# Processing Record 26 of Set 8 | imeni zhelyabova
# Processing Record 27 of Set 8 | kuytun
# Processing Record 28 of Set 8 | seymchan
# Processing Record 29 of Set 8 | lafia
# Processing Record 30 of Set 8 | buchanan
# Processing Record 31 of Set 8 | berbera
# Processing Record 32 of Set 8 | morgan city
# Processing Record 33 of Set 8 | zelenoborskiy
# Processing Record 34 of Set 8 | divnomorskoye
# Processing Record 35 of Set 8 | yuci
# Processing Record 36 of Set 8 | krasnoarmeysk
# Processing Record 37 of Set 8 | burica
# City not found. Skipping...
# Processing Record 38 of Set 8 | sao filipe
# Processing Record 39 of Set 8 | bermejillo
# Processing Record 40 of Set 8 | navahrudak
# Processing Record 41 of Set 8 | el faiyum
# City not found. Skipping...
# Processing Record 42 of Set 8 | constitucion
# Processing Record 43 of Set 8 | waingapu
# Processing Record 44 of Set 8 | vardo
# Processing Record 45 of Set 8 | leh
# Processing Record 46 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 8 | pangody
# Processing Record 48 of Set 8 | hobyo
# Processing Record 49 of Set 8 | okhotsk
# Processing Record 50 of Set 8 | matara
# Processing Record 1 of Set 9 | kitimat
# Processing Record 2 of Set 9 | igrim
# Processing Record 3 of Set 9 | grand gaube
# Processing Record 4 of Set 9 | ondangwa
# Processing Record 5 of Set 9 | esperance
# Processing Record 6 of Set 9 | beringovskiy
# Processing Record 7 of Set 9 | vila velha
# Processing Record 8 of Set 9 | vao
# Processing Record 9 of Set 9 | saint-georges
# Processing Record 10 of Set 9 | balabac
# Processing Record 11 of Set 9 | rovaniemi
# Processing Record 12 of Set 9 | ulladulla
# Processing Record 13 of Set 9 | shimoda
# Processing Record 14 of Set 9 | nizhniy kuranakh
# Processing Record 15 of Set 9 | rantepao
# Processing Record 16 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 17 of Set 9 | krasnyy yar
# Processing Record 18 of Set 9 | mayo
# Processing Record 19 of Set 9 | muzhi
# Processing Record 20 of Set 9 | koplik
# Processing Record 21 of Set 9 | doume
# Processing Record 22 of Set 9 | durusu
# Processing Record 23 of Set 9 | marystown
# Processing Record 24 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 9 | north bend
# Processing Record 26 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 27 of Set 9 | verdun
# Processing Record 28 of Set 9 | linxia
# Processing Record 29 of Set 9 | liku
# Processing Record 30 of Set 9 | asosa
# Processing Record 31 of Set 9 | narsaq
# Processing Record 32 of Set 9 | serebryanyy bor
# Processing Record 33 of Set 9 | belyy
# Processing Record 34 of Set 9 | subotica
# Processing Record 35 of Set 9 | beroroha
# Processing Record 36 of Set 9 | bolshaya glushitsa
# Processing Record 37 of Set 9 | jiazi
# Processing Record 38 of Set 9 | cravo norte
# Processing Record 39 of Set 9 | dekar
# Processing Record 40 of Set 9 | altamont
# Processing Record 41 of Set 9 | itaituba
# Processing Record 42 of Set 9 | riverton
# Processing Record 43 of Set 9 | charlestown
# Processing Record 44 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 45 of Set 9 | fortuna
# Processing Record 46 of Set 9 | muros
# Processing Record 47 of Set 9 | omsukchan
# Processing Record 48 of Set 9 | yar-sale
# Processing Record 49 of Set 9 | nouakchott
# Processing Record 50 of Set 9 | murud
# Processing Record 1 of Set 10 | bilma
# Processing Record 2 of Set 10 | orizona
# Processing Record 3 of Set 10 | ranong
# Processing Record 4 of Set 10 | tarko-sale
# Processing Record 5 of Set 10 | savannah bight
# Processing Record 6 of Set 10 | najran
# Processing Record 7 of Set 10 | mwingi
# Processing Record 8 of Set 10 | karratha
# Processing Record 9 of Set 10 | maraba
# Processing Record 10 of Set 10 | codrington
# Processing Record 11 of Set 10 | mana
# Processing Record 12 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 10 | meghri
# Processing Record 14 of Set 10 | banda aceh
# Processing Record 15 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 16 of Set 10 | diamantino
# Processing Record 17 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 18 of Set 10 | agadez
# Processing Record 19 of Set 10 | hanover
# Processing Record 20 of Set 10 | kichera
# Processing Record 21 of Set 10 | farah
# Processing Record 22 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 23 of Set 10 | hohhot
# Processing Record 24 of Set 10 | ahvaz
# Processing Record 25 of Set 10 | ust-nera
# Processing Record 26 of Set 10 | huaiyin
# Processing Record 27 of Set 10 | maldonado
# Processing Record 28 of Set 10 | chapais
# Processing Record 29 of Set 10 | vila franca do campo
# Processing Record 30 of Set 10 | dordrecht
# Processing Record 31 of Set 10 | sakakah
# Processing Record 32 of Set 10 | carutapera
# Processing Record 33 of Set 10 | kuusamo
# Processing Record 34 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 35 of Set 10 | wageningen
# Processing Record 36 of Set 10 | daru
# Processing Record 37 of Set 10 | astoria
# Processing Record 38 of Set 10 | elmadag
# Processing Record 39 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 10 | ciamis
# Processing Record 41 of Set 10 | labuhan
# Processing Record 42 of Set 10 | porto novo
# Processing Record 43 of Set 10 | port moresby
# Processing Record 44 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 10 | moengo
# Processing Record 46 of Set 10 | neiafu
# Processing Record 47 of Set 10 | morondava
# Processing Record 48 of Set 10 | grindavik
# Processing Record 49 of Set 10 | wattegama
# Processing Record 50 of Set 10 | slavonski brod
# Processing Record 1 of Set 11 | merauke
# Processing Record 2 of Set 11 | arroyo
# Processing Record 3 of Set 11 | shaowu
# Processing Record 4 of Set 11 | inhambane
# Processing Record 5 of Set 11 | cayenne
# Processing Record 6 of Set 11 | armidale
# Processing Record 7 of Set 11 | araouane
# Processing Record 8 of Set 11 | hof
# Processing Record 9 of Set 11 | krasnyy chikoy
# Processing Record 10 of Set 11 | chimbote
# Processing Record 11 of Set 11 | amahai
# Processing Record 12 of Set 11 | virtsu
# Processing Record 13 of Set 11 | santa cruz de la palma
# Processing Record 14 of Set 11 | male
# Processing Record 15 of Set 11 | stornoway
# Processing Record 16 of Set 11 | college
# Processing Record 17 of Set 11 | caravelas
# Processing Record 18 of Set 11 | baykit
# Processing Record 19 of Set 11 | coimbra
# Processing Record 20 of Set 11 | marzuq
# Processing Record 21 of Set 11 | kruisfontein
# Processing Record 22 of Set 11 | tucumcari
# Processing Record 23 of Set 11 | sungaipenuh
# Processing Record 24 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 11 | coihaique
# Processing Record 26 of Set 11 | gat
# Processing Record 27 of Set 11 | yaan
# Processing Record 28 of Set 11 | pitimbu
# Processing Record 29 of Set 11 | nishihara
# Processing Record 30 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 11 | belmonte
# Processing Record 32 of Set 11 | lafiagi
# Processing Record 33 of Set 11 | maumere
# Processing Record 34 of Set 11 | revelstoke
# Processing Record 35 of Set 11 | thurso
# Processing Record 36 of Set 11 | tambo
# Processing Record 37 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 11 | rio tercero
# Processing Record 40 of Set 11 | mogadishu
# Processing Record 41 of Set 11 | ust-maya
# Processing Record 42 of Set 11 | yenagoa
# Processing Record 43 of Set 11 | malanje
# Processing Record 44 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 11 | atar
# Processing Record 46 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 11 | pasni
# Processing Record 48 of Set 11 | oktyabrskoye
# Processing Record 49 of Set 11 | rudnya
# Processing Record 50 of Set 11 | kathmandu
# Processing Record 1 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 2 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 12 | teguldet
# Processing Record 4 of Set 12 | noumea
# Processing Record 5 of Set 12 | palmer
# Processing Record 6 of Set 12 | hermagor
# Processing Record 7 of Set 12 | mangai
# Processing Record 8 of Set 12 | klaksvik
# Processing Record 9 of Set 12 | vengerovo
# Processing Record 10 of Set 12 | ranau
# Processing Record 11 of Set 12 | grand-santi
# Processing Record 12 of Set 12 | tahe
# Processing Record 13 of Set 12 | anzio
# Processing Record 14 of Set 12 | mandalay
# Processing Record 15 of Set 12 | tera
# Processing Record 16 of Set 12 | port blair
# Processing Record 17 of Set 12 | buraydah
# Processing Record 18 of Set 12 | kavaratti
# Processing Record 19 of Set 12 | san felipe
# Processing Record 20 of Set 12 | zyryanka
# Processing Record 21 of Set 12 | porto murtinho
# Processing Record 22 of Set 12 | banjar
# Processing Record 23 of Set 12 | austin
# Processing Record 24 of Set 12 | marietta
# Processing Record 25 of Set 12 | esna
# Processing Record 26 of Set 12 | celestun
# Processing Record 27 of Set 12 | general roca
# Processing Record 28 of Set 12 | mersing
# Processing Record 29 of Set 12 | manga
# Processing Record 30 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 31 of Set 12 | mumford
# Processing Record 32 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 12 | san rafael
# Processing Record 34 of Set 12 | coquimbo
# Processing Record 35 of Set 12 | yuyao
# Processing Record 36 of Set 12 | pemangkat
# Processing Record 37 of Set 12 | mananjary
# Processing Record 38 of Set 12 | san jose
# Processing Record 39 of Set 12 | viedma
# Processing Record 40 of Set 12 | vrangel
# Processing Record 41 of Set 12 | olafsvik
# Processing Record 42 of Set 12 | dovbysh
# Processing Record 43 of Set 12 | san cristobal
# Processing Record 44 of Set 12 | omboue
# Processing Record 45 of Set 12 | boa vista
# Processing Record 46 of Set 12 | haflong
# Processing Record 47 of Set 12 | ponta delgada
# Processing Record 48 of Set 12 | teknaf
# Processing Record 49 of Set 12 | takoradi
# Processing Record 50 of Set 12 | kilindoni
# Processing Record 1 of Set 13 | cahors
# Processing Record 2 of Set 13 | salinopolis
# Processing Record 3 of Set 13 | kushima
# Processing Record 4 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 5 of Set 13 | mount pleasant
# Processing Record 6 of Set 13 | dibaya
# City not found. Skipping...
# Processing Record 7 of Set 13 | joao pinheiro
# Processing Record 8 of Set 13 | huayucachi
# Processing Record 9 of Set 13 | springdale
# Processing Record 10 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 13 | tura
# Processing Record 12 of Set 13 | hualmay
# Processing Record 13 of Set 13 | poquoson
# Processing Record 14 of Set 13 | veraval
# Processing Record 15 of Set 13 | mandalgovi
# Processing Record 16 of Set 13 | camacha
# Processing Record 17 of Set 13 | saint-louis
# Processing Record 18 of Set 13 | tautira
# Processing Record 19 of Set 13 | carballo
# Processing Record 20 of Set 13 | whitehorse
# Processing Record 21 of Set 13 | shenyang
# Processing Record 22 of Set 13 | halifax
# Processing Record 23 of Set 13 | senador guiomard
# Processing Record 24 of Set 13 | teeli
# Processing Record 25 of Set 13 | ambon
# Processing Record 26 of Set 13 | thinadhoo
# Processing Record 27 of Set 13 | mancio lima
# Processing Record 28 of Set 13 | luwuk
# Processing Record 29 of Set 13 | ngunguru
# Processing Record 30 of Set 13 | tromso
# Processing Record 31 of Set 13 | marrakesh
# Processing Record 32 of Set 13 | conde
# Processing Record 33 of Set 13 | agirish
# Processing Record 34 of Set 13 | piacabucu
# Processing Record 35 of Set 13 | krasnoselkup
# Processing Record 36 of Set 13 | serenje
# Processing Record 37 of Set 13 | henzada
# City not found. Skipping...
# Processing Record 38 of Set 13 | talaya
# Processing Record 39 of Set 13 | moindou
# Processing Record 40 of Set 13 | coari
# Processing Record 41 of Set 13 | challapata
# Processing Record 42 of Set 13 | hrodna
# Processing Record 43 of Set 13 | felanitx
# Processing Record 44 of Set 13 | dabola
# Processing Record 45 of Set 13 | aykhal
# Processing Record 46 of Set 13 | razole
# Processing Record 47 of Set 13 | lieksa
# Processing Record 48 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 50 of Set 13 | sinegorskiy
# Processing Record 1 of Set 14 | monrovia
# Processing Record 2 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 3 of Set 14 | dejen
# Processing Record 4 of Set 14 | skibbereen
# Processing Record 5 of Set 14 | auki
# Processing Record 6 of Set 14 | hildburghausen
# Processing Record 7 of Set 14 | paka
# Processing Record 8 of Set 14 | ensley
# Processing Record 9 of Set 14 | boyolangu
# Processing Record 10 of Set 14 | izhma
# Processing Record 11 of Set 14 | ganassi
# Processing Record 12 of Set 14 | hilton head island
# Processing Record 13 of Set 14 | rawlins
# Processing Record 14 of Set 14 | yeppoon
# Processing Record 15 of Set 14 | monticello
# Processing Record 16 of Set 14 | abu dhabi
# Processing Record 17 of Set 14 | nadvoitsy
# Processing Record 18 of Set 14 | beloha
# Processing Record 19 of Set 14 | barghat
# Processing Record 20 of Set 14 | porto belo
# Processing Record 21 of Set 14 | vanimo
# Processing Record 22 of Set 14 | mahon
# Processing Record 23 of Set 14 | perpignan
# Processing Record 24 of Set 14 | kargasok
# Processing Record 25 of Set 14 | kadhan
# Processing Record 26 of Set 14 | ustka
# Processing Record 27 of Set 14 | gaur
# Processing Record 28 of Set 14 | lata
# Processing Record 29 of Set 14 | half moon bay
# Processing Record 30 of Set 14 | doha
# Processing Record 31 of Set 14 | kralendijk
# Processing Record 32 of Set 14 | la union
# Processing Record 33 of Set 14 | nantucket
# Processing Record 34 of Set 14 | shawnee
# Processing Record 35 of Set 14 | teluknaga
# Processing Record 36 of Set 14 | barentu
# Processing Record 37 of Set 14 | ust-koksa
# Processing Record 38 of Set 14 | marsh harbour
# Processing Record 39 of Set 14 | palampur
# Processing Record 40 of Set 14 | bria
# Processing Record 41 of Set 14 | sibolga
# Processing Record 42 of Set 14 | makakilo city
# Processing Record 43 of Set 14 | ancud
# Processing Record 44 of Set 14 | malartic
# Processing Record 45 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 14 | batagay-alyta
# Processing Record 47 of Set 14 | beipiao
# Processing Record 48 of Set 14 | kozhva
# Processing Record 49 of Set 14 | kenai
# Processing Record 50 of Set 14 | honningsvag
# Processing Record 1 of Set 15 | ternate
# Processing Record 2 of Set 15 | fenelon falls
# Processing Record 3 of Set 15 | mount abu
# Processing Record 4 of Set 15 | moche
# Processing Record 5 of Set 15 | jackson
# Processing Record 6 of Set 15 | bushehr
# Processing Record 7 of Set 15 | raglan
# Processing Record 8 of Set 15 | warora
# Processing Record 9 of Set 15 | norfolk
# Processing Record 10 of Set 15 | jinchang
# Processing Record 11 of Set 15 | yambio
# Processing Record 12 of Set 15 | ziro
# Processing Record 13 of Set 15 | rocha
# Processing Record 14 of Set 15 | grimari
# City not found. Skipping...
# Processing Record 15 of Set 15 | kokopo
# Processing Record 16 of Set 15 | mazamari
# Processing Record 17 of Set 15 | bossangoa
# Processing Record 18 of Set 15 | carauari
# Processing Record 19 of Set 15 | aasiaat
# Processing Record 20 of Set 15 | ozinki
# Processing Record 21 of Set 15 | sao felix do xingu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 658

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Albany  42.6001  -73.9662     55.56        90          73        4.00
# 1       Pevek  69.7008  170.3133     31.14        92         100        9.17
# 2       Bluff -46.6000  168.3333     45.81        63          96       23.15
# 3     Rikitea -23.1203 -134.9692     68.97        66          12       21.54
# 4  Butaritari   3.0707  172.7902     82.09        72          19       14.05
# 5      Mehamn  71.0357   27.8492     42.71        81         100       10.36
# 6    Acurenam   1.0322   10.6488     68.41        99         100        2.21
# 7      Marawi   7.9986  124.2928     74.84        81          98        2.55
# 8       Yurla  59.3259   54.3223     41.94        76          99        6.76
# 9       Tiksi  71.6872  128.8694     21.74        83          97       15.86
#
#   Country Weather Description
# 0      US       broken clouds
# 1      RU          light snow
# 2      NZ     overcast clouds
# 3      PF          few clouds
# 4      KI          few clouds
# 5      NO     overcast clouds
# 6      GQ     overcast clouds
# 7      PH     overcast clouds
# 8      RU     overcast clouds
# 9      RU     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Weather Description"]
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Albany  42.6001  -73.9662     55.56        90          73        4.00
# 1       Pevek  69.7008  170.3133     31.14        92         100        9.17
# 2       Bluff -46.6000  168.3333     45.81        63          96       23.15
# 3     Rikitea -23.1203 -134.9692     68.97        66          12       21.54
# 4  Butaritari   3.0707  172.7902     82.09        72          19       14.05
#
#   Country Weather Description
# 0      US       broken clouds
# 1      RU          light snow
# 2      NZ     overcast clouds
# 3      PF          few clouds
# 4      KI          few clouds

# %%
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Albany      US  42.6001  -73.9662     55.56        90          73
# 1       Pevek      RU  69.7008  170.3133     31.14        92         100
# 2       Bluff      NZ -46.6000  168.3333     45.81        63          96
# 3     Rikitea      PF -23.1203 -134.9692     68.97        66          12
# 4  Butaritari      KI   3.0707  172.7902     82.09        72          19
#
#    Wind Speed Weather Description
# 0        4.00       broken clouds
# 1        9.17          light snow
# 2       23.15     overcast clouds
# 3       21.54          few clouds
# 4       14.05          few clouds

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
#create the output file(csv)
output_data_file="WeatherPy_Database.csv"
#export the city_data into a csv.
city_data_df.to_csv(output_data_file,index_label="City_ID")
